# %%
import pandas as pd
import numpy as np
import math as mt
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

# %%
data = pd.read_csv('E:/work tests/data.csv')

# %%
X_unknown_circle = 3
Y_unknown_circle = -2
min_distance = float("inf")
predicted_color = ''

# %%
def euclidean_distance(x1, x2,y1,y2):
    x = (x1-x2)**2
    y = (y1-y2)**2
    return mt.sqrt(np.sum((x+y)))

# %%
for i in range(50):
    X = data.iloc[i,0]
    Y = data.iloc[i,1]
    distance = euclidean_distance(X_unknown_circle,X,Y_unknown_circle,Y)
    if distance < min_distance:
        min_distance = distance
        predicted_color = data.iloc[i,2]

# %%
print(predicted_color)
# Out:
# red

# %%
y_plane = data['color']
x,y = data['x'],data['y']
plt.figure()
cmap = ListedColormap(['#0000FF','#FF0000','#00FF00'])
plt.scatter(x,y,c=y_plane,cmap=cmap,edgecolor = 'k',s =10)
plt.plot(X_unknown_circle, Y_unknown_circle, marker = '.',ls='none', ms=7,c=predicted_color)
plt.scatter(X_unknown_circle, Y_unknown_circle, s=100, facecolors='none', edgecolors=predicted_color)
plt.show()
# Out:
# C:\Users\Bumho Nisubire\AppData\Local\Temp\ipykernel_8212\596413321.py:5: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(x,y,c=y_plane,cmap=cmap,edgecolor = 'k',s =10)
